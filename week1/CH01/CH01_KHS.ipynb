# %% [markdown]
# # Chapter 1. 데이터, 알파 벡터, 포트폴리오

# %% [markdown]
# - 알고리즘(Alogorithm) : 목표를 달성하고자 설계된 일련의 절차나 규칙
# - 머신러닝(ML) : 예측 오차 최소화 같은 목표를 달성하고자 데이터에서 규칙이나 패턴을 학습하는 알고리즘
#     - 머신러닝 이전 (알고리즘 트레이딩 : 비용 효율적인 주문을 주로 활용)
#
# => 시장을 관찰하고 미래에 관한 기대를 형성하는 데이터를 분석하는 것이 중요
#
# - 액티브 투자운영(Active investment management)
#     - 수익을 창출하기 위한 포트폴리오 관리
#     - 목표 : 벤치마크를 초과하는 포트폴리오 수익으로 정의되는 알파를 생성하는 것
#
# - 정보 비율 : 투자 운용의 가치를 포트폴리오와 해당 수익률의 변동성에 벤치마크 간 수익률 차이의 비율로 표현
#     - 정보계수(IC, Information Coefficient) : 결과와의 순위 상관관계로 예측의 질을 측정
#     - 전략 폭(Breadth of strategy) : 예측에 대한 독립 배팅 수 -> 제곱근
#
#
# - 고빈도 매매 전략
#     - 패시브 전략 : 동일 자산이나 파생 상푸므, 다른 장소에 거래되는 것에 대한 매우 작은 가격차에서 수익을 얻는 차익 거래
#     - 액티브 전략 : 예상이나 추세 조장 행위를 포함하는 전략

# %% [markdown]
# ### 팩터 투자와 스마트 베타 펀드
# - 리스크 팩터의 행태를 식별하고 예측해 투 자 전략을 설계할 때 중요한 초점이 됨
# - 주식 투자는 기업의 사업리스크 / 채권 투자는 부도 리스크 등의 리스크 특성을 활용
# - 1960년대 자산 가격 결정 모델을 통해 수많은 추가 리스크 팩터가 발견 => 계량화 할 수 있는 신호, 속성 또는 미래의 주식 수익률과 역사적으로 상관관계까 있으며, 미래에도 지속될 것이라고 생각되는 변수!
#
# - 멀티팩터 모델(multifactor model)
#     - 시장 포틀폴리오보다 더 넓게 분산화된 리스크로 정의
#     - 가장 중요한 매크로 팩터는
#         - 1. 성장
#         - 2. 인플레이션
#         - 3. 변동성 <br>
#         추가) 인구 통계학적 <br>
#         추가) 시장리스크<br>
#         => 횡당면 주식률을 더 잘 설명한느 3 팩터 모델

# %% [markdown]
# ### 머신러닝 기반 전략의 설계와 진행
# - 이 책의 목적 거래 전략의 설계, 실행, 평가의 전반적인 과정에 머신러닝이 어떻게 부합되는지 설명하는 것 (자산 수익률 예측 ...)
#     - 데이터 소스를 소싱하고 관리하는 방법
#     - 신호 내뇽을 추출하는 정보 특성이나 알파 팩터를 엔지니어링하는 방법
#     - 포트폴리오를 관리하고 전략 성과를 추적하는 방법<br><br>
# - 리서치 스텝 : [예측 데이터 수집 -> 투자 유니버스 정의 -> 알파 팩터 설계 -> 알파 팩터 결합] -> 실행 스텝 : [포트폴리오 최적화 -> 트레이드 실행]
#     - 리서치 스텝
#         - 예측 팩터 : 데이터 소스와 자산 수익률 같은 중요한 전략 입력 변수 간의 체계적인 관계의 일부 측면을 포착하는 것 (Feature Enginerring)
#         - 데이터 마이닝 : 데이터의 왜곡과 같은 잘못된 발견은 신중한 관리가 필요한 요소임
#     - 실행 스텝
#         - 포트폴리오 리스크에 상호작용하고 영향이 있는 특정 리스크 프로파일을 갖음
#         - 포트폴리오 관리에는 투자 목표와 일치하는 포트폴리오의 수익과 리스크의 균형을 맞추려고 포지션의 크기를 최적화하는 것을 포함

# %% [markdown]
# ### 전략 백테스팅
# - 투자 전략을 편향을 갖지 않는 성과 추정치를 얻고자 실행하는 시뮬레이션하는 것
# - 성공적인 알고리즘 트레이딩 전략을 선택할때 중요한 과정
#
# ### 트레이더 알고리즘을 사용하는 데에 추구해야할 목표
# - 1. 우호적인 가격 결정을 목표로 하는 거래 실행 알고리즘
# - 2. 작은 가격 변동으로부터 이익을 얻을 목적으로 하는 단기 거래
# - 3. 다른 시장 참여자의 행동을 예측하는 것을 목표로 하는 행태 거래 전략
# - 4. 절대 및 상대 가격을 기반으로 거래 전략과 수익률 예측
